# %% [markdown]
# # Import Data

# %%
import pandas as pd
import numpy as np

# %%
OWID_URL = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"

df = pd.read_csv(OWID_URL)

df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                   37.75                         0.5
# 1           NaN                   37.75                         0.5
# 2           NaN                   37.75                         0.5
# 3           NaN                   37.75                         0.5
# 4           NaN                   37.75                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                     0.51    41128772
# 1            64.83                     0.51    41128772
# 2            64.83                     0.51    41128772
# 3            64.83                     0.51    41128772
# 4            64.83                     0.51    41128772
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# # Chọn ra những cột trọng tâm

# %%
    cols_to_keep = [
            'iso_code', 'continent', 'location', 'date',
            'total_cases', 'total_deaths', 'new_cases', 'new_deaths',
            'population', 'people_vaccinated', 'people_fully_vaccinated'
        ]

    # Copy tạo bản sao
    df_clean =  df[cols_to_keep].copy()

df_clean
# Out:
#        iso_code continent     location        date  total_cases  total_deaths  \
# 0           AFG      Asia  Afghanistan  2020-01-05          0.0           0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          0.0           0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          0.0           0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          0.0           0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          0.0           0.0
# ...         ...       ...          ...         ...          ...           ...
# 429430      ZWE    Africa     Zimbabwe  2024-07-31     266386.0        5740.0
# 429431      ZWE    Africa     Zimbabwe  2024-08-01     266386.0        5740.0
# 429432      ZWE    Africa     Zimbabwe  2024-08-02     266386.0        5740.0
# 429433      ZWE    Africa     Zimbabwe  2024-08-03     266386.0        5740.0
# 429434      ZWE    Africa     Zimbabwe  2024-08-04     266386.0        5740.0
#
#         new_cases  new_deaths  population  people_vaccinated  \
# 0             0.0         0.0    41128772                NaN
# 1             0.0         0.0    41128772                NaN
# 2             0.0         0.0    41128772                NaN
# 3             0.0         0.0    41128772                NaN
# 4             0.0         0.0    41128772                NaN
# ...           ...         ...         ...                ...
# 429430        0.0         0.0    16320539                NaN
# 429431        0.0         0.0    16320539                NaN
# 429432        0.0         0.0    16320539                NaN
# 429433        0.0         0.0    16320539                NaN
# 429434        0.0         0.0    16320539                NaN
#
#         people_fully_vaccinated
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 429430                      NaN
# 429431                      NaN
# 429432                      NaN
# 429433                      NaN
# 429434                      NaN
#
# [429435 rows x 11 columns]

# %% [markdown]
# # Chuyển đổi dữ liệu ngày

# %%
df_clean['date'] = pd.to_datetime(df_clean['date'])

df_clean
# Out:
#        iso_code continent     location       date  total_cases  total_deaths  \
# 0           AFG      Asia  Afghanistan 2020-01-05          0.0           0.0
# 1           AFG      Asia  Afghanistan 2020-01-06          0.0           0.0
# 2           AFG      Asia  Afghanistan 2020-01-07          0.0           0.0
# 3           AFG      Asia  Afghanistan 2020-01-08          0.0           0.0
# 4           AFG      Asia  Afghanistan 2020-01-09          0.0           0.0
# ...         ...       ...          ...        ...          ...           ...
# 429430      ZWE    Africa     Zimbabwe 2024-07-31     266386.0        5740.0
# 429431      ZWE    Africa     Zimbabwe 2024-08-01     266386.0        5740.0
# 429432      ZWE    Africa     Zimbabwe 2024-08-02     266386.0        5740.0
# 429433      ZWE    Africa     Zimbabwe 2024-08-03     266386.0        5740.0
# 429434      ZWE    Africa     Zimbabwe 2024-08-04     266386.0        5740.0
#
#         new_cases  new_deaths  population  people_vaccinated  \
# 0             0.0         0.0    41128772                NaN
# 1             0.0         0.0    41128772                NaN
# 2             0.0         0.0    41128772                NaN
# 3             0.0         0.0    41128772                NaN
# 4             0.0         0.0    41128772                NaN
# ...           ...         ...         ...                ...
# 429430        0.0         0.0    16320539                NaN
# 429431        0.0         0.0    16320539                NaN
# 429432        0.0         0.0    16320539                NaN
# 429433        0.0         0.0    16320539                NaN
# 429434        0.0         0.0    16320539                NaN
#
#         people_fully_vaccinated
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 429430                      NaN
# 429431                      NaN
# 429432                      NaN
# 429433                      NaN
# 429434                      NaN
#
# [429435 rows x 11 columns]

# %% [markdown]
# # Data Imputation (Missing Data Replacement)

# %%
for col in df_clean.columns:
    missing_data = df_clean[col].isna().sum()
    missing_percent = missing_data/len(df_clean) *100
    print(f"Column <{col}> has missing percent {missing_percent}%")
# Out:
# Column <iso_code> has missing percent 0.0%
# Column <continent> has missing percent 6.176720574708629%
# Column <location> has missing percent 0.0%
# Column <date> has missing percent 0.0%
# Column <total_cases> has missing percent 4.105627161270041%
# Column <total_deaths> has missing percent 4.105627161270041%
# Column <new_cases> has missing percent 4.488688625752442%
# Column <new_deaths> has missing percent 4.384132639398279%
# Column <population> has missing percent 0.0%
# Column <people_vaccinated> has missing percent 81.10726885326068%
# Column <people_fully_vaccinated> has missing percent 81.8223945416652%

# %%
# Sắp xếp dữ liệu theo ĐỊA ĐIỂM và THỜI GIAN để thực hiện việc XỬ LÝ BIẾN ĐỘNG
df_clean = df_clean.sort_values(['location', 'date'])

df_clean
# Out:
#        iso_code continent     location       date  total_cases  total_deaths  \
# 0           AFG      Asia  Afghanistan 2020-01-05          0.0           0.0
# 1           AFG      Asia  Afghanistan 2020-01-06          0.0           0.0
# 2           AFG      Asia  Afghanistan 2020-01-07          0.0           0.0
# 3           AFG      Asia  Afghanistan 2020-01-08          0.0           0.0
# 4           AFG      Asia  Afghanistan 2020-01-09          0.0           0.0
# ...         ...       ...          ...        ...          ...           ...
# 429430      ZWE    Africa     Zimbabwe 2024-07-31     266386.0        5740.0
# 429431      ZWE    Africa     Zimbabwe 2024-08-01     266386.0        5740.0
# 429432      ZWE    Africa     Zimbabwe 2024-08-02     266386.0        5740.0
# 429433      ZWE    Africa     Zimbabwe 2024-08-03     266386.0        5740.0
# 429434      ZWE    Africa     Zimbabwe 2024-08-04     266386.0        5740.0
#
#         new_cases  new_deaths  population  people_vaccinated  \
# 0             0.0         0.0    41128772                NaN
# 1             0.0         0.0    41128772                NaN
# 2             0.0         0.0    41128772                NaN
# 3             0.0         0.0    41128772                NaN
# 4             0.0         0.0    41128772                NaN
# ...           ...         ...         ...                ...
# 429430        0.0         0.0    16320539                NaN
# 429431        0.0         0.0    16320539                NaN
# 429432        0.0         0.0    16320539                NaN
# 429433        0.0         0.0    16320539                NaN
# 429434        0.0         0.0    16320539                NaN
#
#         people_fully_vaccinated
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 429430                      NaN
# 429431                      NaN
# 429432                      NaN
# 429433                      NaN
# 429434                      NaN
#
# [429435 rows x 11 columns]

# %%
#Forward fill + fillna 0
numeric_cols = df.select_dtypes(include=[np.number]).columns
# Đây là kỹ thuật điền giá trị thiếu thông minh cho dữ liệu chuỗi thời gian, còn gọi là Last Observation Carried Forward (LOCF).
# Nếu một quốc gia không báo cáo số liệu hôm nay, giá trị số liệu tổng hợp (như total_cases) sẽ bằng giá trị đã biết gần nhất của chính quốc gia đó.
# Dùng groupby('location') để đảm bảo việc điền chỉ xảy ra trong phạm vi từng quốc gia, không bị ảnh hưởng bởi quốc gia khác.
df[numeric_cols] = df.groupby('location')[numeric_cols].ffill()
# Sau khi ffill, vẫn còn các giá trị thiếu ở những ngày đầu tiên của mỗi quốc gia. Đối với dữ liệu COVID-19, số liệu thiếu ở giai đoạn đầu thường được hiểu là chưa có báo cáo ca nhiễm/tử vong, nên việc điền bằng 0 là hợp lý.
df[numeric_cols] = df[numeric_cols].fillna(0)

# %% [markdown]
# # MOVING AVERAGE: Xử lý BIẾN ĐỘNG/NOISE

# %%
# Do ca mắc có thể biến động mạnh chỉ trong vài ngày làm cho dữ liệu dễ bị nhiễu theo chu kỳ
# Đồng thời dataset đang có nhiều LOCATION khác nhau nên phải nhóm chúng lại với nhau để tính riêng từng rolling

# rolling: nhìn lại N dòng trước
# transform: tính theo nhóm nhưng giữ nguyên số dòng

# Tính cột mới cho cases
df_clean['new_cases_smoothed'] = df_clean.groupby('location')['new_cases'].transform(
    lambda x: x.rolling(7, min_periods=1).mean()
)

# Tính cột mới cho deaths
df_clean['new_death_smoothed'] = df_clean.groupby('location')['new_deaths'].transform(
    lambda x: x.rolling(7, min_periods=1).mean()
)

df_clean
# Out:
#        iso_code continent     location       date  total_cases  total_deaths  \
# 0           AFG      Asia  Afghanistan 2020-01-05          0.0           0.0
# 1           AFG      Asia  Afghanistan 2020-01-06          0.0           0.0
# 2           AFG      Asia  Afghanistan 2020-01-07          0.0           0.0
# 3           AFG      Asia  Afghanistan 2020-01-08          0.0           0.0
# 4           AFG      Asia  Afghanistan 2020-01-09          0.0           0.0
# ...         ...       ...          ...        ...          ...           ...
# 429430      ZWE    Africa     Zimbabwe 2024-07-31     266386.0        5740.0
# 429431      ZWE    Africa     Zimbabwe 2024-08-01     266386.0        5740.0
# 429432      ZWE    Africa     Zimbabwe 2024-08-02     266386.0        5740.0
# 429433      ZWE    Africa     Zimbabwe 2024-08-03     266386.0        5740.0
# 429434      ZWE    Africa     Zimbabwe 2024-08-04     266386.0        5740.0
#
#         new_cases  new_deaths  population  people_vaccinated  \
# 0             0.0         0.0    41128772                NaN
# 1             0.0         0.0    41128772                NaN
# 2             0.0         0.0    41128772                NaN
# 3             0.0         0.0    41128772                NaN
# 4             0.0         0.0    41128772                NaN
# ...           ...         ...         ...                ...
# 429430        0.0         0.0    16320539                NaN
# 429431        0.0         0.0    16320539                NaN
# 429432        0.0         0.0    16320539                NaN
# 429433        0.0         0.0    16320539                NaN
# 429434        0.0         0.0    16320539                NaN
#
#         people_fully_vaccinated  new_cases_smoothed  new_death_smoothed
# 0                           NaN                 0.0                 0.0
# 1                           NaN                 0.0                 0.0
# 2                           NaN                 0.0                 0.0
# 3                           NaN                 0.0                 0.0
# 4                           NaN                 0.0                 0.0
# ...                         ...                 ...                 ...
# 429430                      NaN                 0.0                 0.0
# 429431                      NaN                 0.0                 0.0
# 429432                      NaN                 0.0                 0.0
# 429433                      NaN                 0.0                 0.0
# 429434                      NaN                 0.0                 0.0
#
# [429435 rows x 13 columns]

# %%
# Thư viện hỗ trợ tạo file.parquet
# %pip uninstall pyarrow -y
# %pip install pyarrow==14.0.2
# Out:
# Found existing installation: pyarrow 22.0.0
# Uninstalling pyarrow-22.0.0:
#   Successfully uninstalled pyarrow-22.0.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'E:\Python\COVID19\Data-Preparation\.venv\Lib\site-packages\~yarrow.libs'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'E:\Python\COVID19\Data-Preparation\.venv\Lib\site-packages\~yarrow'.
# You can safely remove it manually.

# %%
df_clean.to_parquet("data/covid_cleaned.parquet", index=False)
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df_clean.to_parquet("data/covid_cleaned.parquet", index=False)
#
# File E:\Python\COVID19\Data-Preparation\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File E:\Python\COVID19\Data-Preparation\.venv\Lib\site-packages\pandas\core\frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
#    (...)   3120 >>> content = f.read()
#    3121 """
#    3122 from pandas.io.parquet import to_parquet
# -> 3124 return to_parquet(
#    3125     self,
#    3126     path,
#    3127     engine,
#    3128     compression=compression,
#    3129     index=index,
#    3130     partition_cols=partition_cols,
#    3131     storage_options=storage_options,
#    3132     **kwargs,
#    3133 )
#
# File E:\Python\COVID19\Data-Preparation\.venv\Lib\site-packages\pandas\io\parquet.py:478, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 if isinstance(partition_cols, str):
#     477     partition_cols = [partition_cols]
# --> 478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     482 impl.write(
#     483     df,
#     484     path_or_buf,
#    (...)    490     **kwargs,
#     491 )
#
# File E:\Python\COVID19\Data-Preparation\.venv\Lib\site-packages\pandas\io\parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File E:\Python\COVID19\Data-Preparation\.venv\Lib\site-packages\pandas\io\parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File E:\Python\COVID19\Data-Preparation\.venv\Lib\site-packages\pandas\core\arrays\arrow\extension_types.py:59
#      57 # register the type with a dummy instance
#      58 _period_type = ArrowPeriodType("D")
# ---> 59 pyarrow.register_extension_type(_period_type)
#      62 class ArrowIntervalType(pyarrow.ExtensionType):
#      63     def __init__(self, subtype, closed: IntervalClosedType) -> None:
#      64         # attributes need to be set first before calling
#      65         # super init (as that calls serialize)
#
# File E:\Python\COVID19\Data-Preparation\.venv\Lib\site-packages\pyarrow\types.pxi:2226, in pyarrow.lib.register_extension_type()
#
# File E:\Python\COVID19\Data-Preparation\.venv\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowKeyError: A type extension with name pandas.period already defined
